# %%
# !nvidia-smi
# Out:
# Mon Aug  9 13:53:47 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   49C    P8    31W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls '/content/drive/MyDrive/Face mask detection using yolov3'
# Out:
# backup	   chart_yolov3_custom.png  darknet_Dont_use#  images.zip
# bad.list   custom_weight	    images	       obj.mp4
# chart.png  darknet		    images_test

# %%
#!unzip '/content/drive/MyDrive/Face mask detection using yolov3/images.zip' -d '/content/drive/MyDrive/Face mask detection using yolov3'

# %%
#!git clone 'https://github.com/AlexeyAB/darknet' '/content/drive/MyDrive/Face mask detection using yolov3/darknet'

# %%
# %cd '/content/drive/MyDrive/Face mask detection using yolov3/darknet'
# Out:
# /content/drive/MyDrive/Face mask detection using yolov3/darknet

# %%
# %cd '/content/drive/MyDrive/Face mask detection using yolov3/darknet'
# !make
# !chmod +x ./darknet
# Out:
# /content/drive/MyDrive/Face mask detection using yolov3/darknet
# chmod +x *.sh

# %%
# %cd '/content/drive/MyDrive/Face mask detection using yolov3'
# !ls
# Out:
# /content/drive/MyDrive/Face mask detection using yolov3
# backup	       darknet		  images       images.zip
# custom_weight  darknet_Dont_use#  images_test

# %%
# %cd '/content/drive/MyDrive/Face mask detection using yolov3'
# Out:
# /content/drive/MyDrive/Face mask detection using yolov3

# %%
# !python images/creating-files-data-and-name.py

# %%
# !python images/creating-train-and-test-txt-files.py

# %%
# %cd '/content/drive/MyDrive/Face mask detection using yolov3'
# Out:
# /content/drive/MyDrive/Face mask detection using yolov3

# %%
# !ls
# Out:
# backup	       darknet		  images       images.zip
# custom_weight  darknet_Dont_use#  images_test

# %%
# !darknet/darknet detector train images/labelled_data.data darknet/cfg/yolov3_custom.cfg  custom_weight/darknet53.conv.74 -dont_show

# %%
# %cd '/content/drive/MyDrive/Face mask detection using yolov3'

# !darknet/darknet
# Out:
# /content/drive/MyDrive/Face mask detection using yolov3
# usage: darknet/darknet <function>

# %%
# !ls
# Out:
# backup	       darknet		  images       images.zip
# custom_weight  darknet_Dont_use#  images_test

# %%
# !ls
# Out:
# backup	   chart_yolov3_custom.png  darknet	       images	    images.zip
# chart.png  custom_weight	    darknet_Dont_use#  images_test  obj.mp4

# %%
# !python images_test/creating-files-data-and-name.py

# %%
# !python images_test/creating-train-and-test-txt-files.py

# %%
#training
# %cd '/content/drive/MyDrive/Face mask detection using yolov3'

# !darknet/darknet detector train images/labelled_data.data darknet/cfg/yolov3_custom.cfg  backup/yolov3_custom_last.weights -dont_show

# %%
# %cd '/content/drive/MyDrive/Face mask detection using yolov3/darknet'

#Prediction on video use all paths as it is instead move data to these locations also uncomment the testing in cfg

# !./darknet detector demo data/labelled_data.data cfg/yolov3_custom.cfg data/yolov3_custom_final.weights -dont_show video/obj2.mp4 -thresh 0.5 -i 0 -out_filename data/results2.avi
# Out:
# Streaming output truncated to the last 5000 lines.
#
#  cvWriteFrame
# Objects:
#
# with_mask: 100%
#
# FPS:13.0 	 AVG_FPS:13.4
#
#  cvWriteFrame
# Objects:
#
# with_mask: 100%
#
# FPS:12.9 	 AVG_FPS:13.4
#
#  cvWriteFrame
# Objects:
#
# with_mask: 99%
#
# FPS:12.9 	 AVG_FPS:13.4
#
#  cvWriteFrame
# Objects:
#
# with_mask: 100%
#
# FPS:12.8 	 AVG_FPS:13.4
#
#  cvWriteFrame
# Objects:
#
# with_mask: 100%
#
# FPS:13.0 	 AVG_FPS:13.4
#
#  cvWriteFrame
# Objects:
#
# with_mask: 100%
#
# FPS:12.8 	 AVG_FPS:13.4
#
#  cvWriteFrame
# Objects:
#
# with_mask: 100%
#
# FPS:12.9 	 AVG_FPS:13.4
#
#  cvWriteFrame
# Objects:
#
# with_mask: 100%
#
# FPS:12.8 	 AVG_FPS:13.4
#
#  cvWriteFrame
# Objects:
#
# with_mask: 84%
#
# FPS:12.7 	 AVG_FPS:13.4
#
#  cvWriteFrame
# Objects:
#
# with_mask: 98%
#
# FPS:12.6 	 AVG_FPS:13.4
#
#  cvWriteFrame
# Objects:
#
# with_mask: 99%
#
# FPS:12.7 	 AVG_FPS:13.4
#
#  cvWriteFrame
# Objects:
#
# with_mask: 98%
#
# FPS:12.6 	 AVG_FPS:13.4
#
#  cvWriteFrame
# ...
